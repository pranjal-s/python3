# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# indices
data = pd.Series(['a','b','c','d'],index=['i','ii','iii','iv'])
print(data)
print(data.values)
print(data[1:3])
print(data['ii':'iii'])
# Out:
# i      a
# ii     b
# iii    c
# iv     d
# dtype: object
# ['a' 'b' 'c' 'd']
# ii     b
# iii    c
# dtype: object
# ii     b
# iii    c
# dtype: object

# %%
# dict
data2 = pd.Series({2:'a',1:'b',3:'c'})
print(data2)
# Out:
# 2    a
# 1    b
# 3    c
# dtype: object

# %%
# data_frame
area = pd.Series({'CA':10,'PA':20,'NY':30})
peri = pd.Series({'CA':3,'PA':6,'NY':9})
data3 = pd.DataFrame({'area':area,'peri':peri})
print(data3)
# Out:
#     area  peri
# CA    10     3
# PA    20     6
# NY    30     9

# %%
# tabular
info = np.random.randint(10, size=(3,2))
print(info)
data4 = pd.DataFrame(info,columns=['foo','bar'],index=['i','ii','iii'])
print(data4)

np.all(data4.values == info)
# Out:
# [[9 8]
#  [3 2]
#  [9 6]]
#      foo  bar
# i      9    8
# ii     3    2
# iii    9    6
# True

# %%
# multi
index = pd.MultiIndex.from_product([[2013,2014],[1,2]],names=['yr','visit'])
columns = pd.MultiIndex.from_product([['B','G','S'],['H','T']],names=['sub','type'])
data = np.random.randint(100,size=(4,6))-50

data5 = pd.DataFrame(data,index=index,columns=columns)

data5.style.background_gradient(cmap=sns.light_palette("green", as_cmap=True))
# Out:
# <style type="text/css">
# #T_93210_row0_col0, #T_93210_row0_col1, #T_93210_row0_col2, #T_93210_row1_col5, #T_93210_row3_col3, #T_93210_row3_col4 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_93210_row0_col3, #T_93210_row1_col2, #T_93210_row1_col4, #T_93210_row2_col0, #T_93210_row2_col1, #T_93210_row2_col5 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_93210_row0_col4 {
#   background-color: #73b873;
#   color: #f1f1f1;
# }
# #T_93210_row0_col5 {
#   background-color: #219021;
#   color: #f1f1f1;
# }
# #T_93210_row1_col0 {
#   background-color: #7fbe7f;
#   color: #000000;
# }
# #T_93210_row1_col1 {
#   background-color: #168b16;
#   color: #f1f1f1;
# }
# #T_93210_row1_col3 {
#   background-color: #d3e7d3;
#   color: #000000;
# }
# #T_93210_row2_col2 {
#   background-color: #7bbc7b;
#   color: #000000;
# }
# #T_93210_row2_col3 {
#   background-color: #6eb66e;
#   color: #f1f1f1;
# }
# #T_93210_row2_col4 {
#   background-color: #c5e0c5;
#   color: #000000;
# }
# #T_93210_row3_col0 {
#   background-color: #91c791;
#   color: #000000;
# }
# #T_93210_row3_col1 {
#   background-color: #0b850b;
#   color: #f1f1f1;
# }
# #T_93210_row3_col2 {
#   background-color: #60af60;
#   color: #f1f1f1;
# }
# #T_93210_row3_col5 {
#   background-color: #bcdcbc;
#   color: #000000;
# }
# </style>
# <table id="T_93210_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >sub</th>
#       <th class="col_heading level0 col0" colspan="2">B</th>
#       <th class="col_heading level0 col2" colspan="2">G</th>
#       <th class="col_heading level0 col4" colspan="2">S</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >type</th>
#       <th class="col_heading level1 col0" >H</th>
#       <th class="col_heading level1 col1" >T</th>
#       <th class="col_heading level1 col2" >H</th>
#       <th class="col_heading level1 col3" >T</th>
#       <th class="col_heading level1 col4" >H</th>
#       <th class="col_heading level1 col5" >T</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >yr</th>
#       <th class="index_name level1" >visit</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_93210_level0_row0" class="row_heading level0 row0" rowspan="2">2013</th>
#       <th id="T_93210_level1_row0" class="row_heading level1 row0" >1</th>
#       <td id="T_93210_row0_col0" class="data row0 col0" >43</td>
#       <td id="T_93210_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_93210_row0_col2" class="data row0 col2" >34</td>
#       <td id="T_93210_row0_col3" class="data row0 col3" >-46</td>
#       <td id="T_93210_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_93210_row0_col5" class="data row0 col5" >-11</td>
#     </tr>
#     <tr>
#       <th id="T_93210_level1_row1" class="row_heading level1 row1" >2</th>
#       <td id="T_93210_row1_col0" class="data row1 col0" >9</td>
#       <td id="T_93210_row1_col1" class="data row1 col1" >-2</td>
#       <td id="T_93210_row1_col2" class="data row1 col2" >-25</td>
#       <td id="T_93210_row1_col3" class="data row1 col3" >-37</td>
#       <td id="T_93210_row1_col4" class="data row1 col4" >-27</td>
#       <td id="T_93210_row1_col5" class="data row1 col5" >-6</td>
#     </tr>
#     <tr>
#       <th id="T_93210_level0_row2" class="row_heading level0 row2" rowspan="2">2014</th>
#       <th id="T_93210_level1_row2" class="row_heading level1 row2" >1</th>
#       <td id="T_93210_row2_col0" class="data row2 col0" >-20</td>
#       <td id="T_93210_row2_col1" class="data row2 col1" >-40</td>
#       <td id="T_93210_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_93210_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_93210_row2_col4" class="data row2 col4" >-18</td>
#       <td id="T_93210_row2_col5" class="data row2 col5" >-41</td>
#     </tr>
#     <tr>
#       <th id="T_93210_level1_row3" class="row_heading level1 row3" >2</th>
#       <td id="T_93210_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_93210_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_93210_row3_col2" class="data row3 col2" >10</td>
#       <td id="T_93210_row3_col3" class="data row3 col3" >41</td>
#       <td id="T_93210_row3_col4" class="data row3 col4" >28</td>
#       <td id="T_93210_row3_col5" class="data row3 col5" >-34</td>
#     </tr>
#   </tbody>
# </table>

# %%
data5.style.bar(subset=['G'],align='mid', color=['#d65f5f', '#5fba7d'])
# Out:
# <style type="text/css">
# #T_84642_row0_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 42.4%, #5fba7d 42.4%, #5fba7d 100.0%, transparent 100.0%);
# }
# #T_84642_row0_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 52.9%, transparent 52.9%);
# }
# #T_84642_row1_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 42.4%, transparent 42.4%);
# }
# #T_84642_row1_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 10.3%, #d65f5f 10.3%, #d65f5f 52.9%, transparent 52.9%);
# }
# #T_84642_row2_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 42.4%, #5fba7d 42.4%, #5fba7d 47.5%, transparent 47.5%);
# }
# #T_84642_row2_col3 {
#   width: 10em;
#   height: 80%;
# }
# #T_84642_row3_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 42.4%, #5fba7d 42.4%, #5fba7d 59.3%, transparent 59.3%);
# }
# #T_84642_row3_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 52.9%, #5fba7d 52.9%, #5fba7d 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_84642_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >sub</th>
#       <th class="col_heading level0 col0" colspan="2">B</th>
#       <th class="col_heading level0 col2" colspan="2">G</th>
#       <th class="col_heading level0 col4" colspan="2">S</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >type</th>
#       <th class="col_heading level1 col0" >H</th>
#       <th class="col_heading level1 col1" >T</th>
#       <th class="col_heading level1 col2" >H</th>
#       <th class="col_heading level1 col3" >T</th>
#       <th class="col_heading level1 col4" >H</th>
#       <th class="col_heading level1 col5" >T</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >yr</th>
#       <th class="index_name level1" >visit</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_84642_level0_row0" class="row_heading level0 row0" rowspan="2">2013</th>
#       <th id="T_84642_level1_row0" class="row_heading level1 row0" >1</th>
#       <td id="T_84642_row0_col0" class="data row0 col0" >43</td>
#       <td id="T_84642_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_84642_row0_col2" class="data row0 col2" >34</td>
#       <td id="T_84642_row0_col3" class="data row0 col3" >-46</td>
#       <td id="T_84642_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_84642_row0_col5" class="data row0 col5" >-11</td>
#     </tr>
#     <tr>
#       <th id="T_84642_level1_row1" class="row_heading level1 row1" >2</th>
#       <td id="T_84642_row1_col0" class="data row1 col0" >9</td>
#       <td id="T_84642_row1_col1" class="data row1 col1" >-2</td>
#       <td id="T_84642_row1_col2" class="data row1 col2" >-25</td>
#       <td id="T_84642_row1_col3" class="data row1 col3" >-37</td>
#       <td id="T_84642_row1_col4" class="data row1 col4" >-27</td>
#       <td id="T_84642_row1_col5" class="data row1 col5" >-6</td>
#     </tr>
#     <tr>
#       <th id="T_84642_level0_row2" class="row_heading level0 row2" rowspan="2">2014</th>
#       <th id="T_84642_level1_row2" class="row_heading level1 row2" >1</th>
#       <td id="T_84642_row2_col0" class="data row2 col0" >-20</td>
#       <td id="T_84642_row2_col1" class="data row2 col1" >-40</td>
#       <td id="T_84642_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_84642_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_84642_row2_col4" class="data row2 col4" >-18</td>
#       <td id="T_84642_row2_col5" class="data row2 col5" >-41</td>
#     </tr>
#     <tr>
#       <th id="T_84642_level1_row3" class="row_heading level1 row3" >2</th>
#       <td id="T_84642_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_84642_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_84642_row3_col2" class="data row3 col2" >10</td>
#       <td id="T_84642_row3_col3" class="data row3 col3" >41</td>
#       <td id="T_84642_row3_col4" class="data row3 col4" >28</td>
#       <td id="T_84642_row3_col5" class="data row3 col5" >-34</td>
#     </tr>
#   </tbody>
# </table>

# %%
# aggregation

rng = np.random.RandomState(0)
ds = pd.Series(rng.rand(5))
df = pd.DataFrame({'A':rng.rand(5),'B':rng.rand(5)})

print(ds.mean())
print(df.mean())
# Out:
# 0.567060845741438
# A    0.664472
# B    0.577059
# dtype: float64

# %%
# groupby

df = sns.load_dataset('planets')

# for each method, summarize the mean of orbital_period
df.groupby('method')['orbital_period'].median()
# Out:
# method
# Astrometry                         631.180000
# Eclipse Timing Variations         4343.500000
# Imaging                          27500.000000
# Microlensing                      3300.000000
# Orbital Brightness Modulation        0.342887
# Pulsar Timing                       66.541900
# Pulsation Timing Variations       1170.000000
# Radial Velocity                    360.200000
# Transit                              5.714932
# Transit Timing Variations           57.011000
# Name: orbital_period, dtype: float64

# %%
# stat summary

df.groupby('method')['orbital_period'].describe()
# Out:
#                                count           mean            std  \
# method
# Astrometry                       2.0     631.180000     544.217663
# Eclipse Timing Variations        9.0    4751.644444    2499.130945
# Imaging                         12.0  118247.737500  213978.177277
# Microlensing                     7.0    3153.571429    1113.166333
# Orbital Brightness Modulation    3.0       0.709307       0.725493
# Pulsar Timing                    5.0    7343.021201   16313.265573
# Pulsation Timing Variations      1.0    1170.000000            NaN
# Radial Velocity                553.0     823.354680    1454.926210
# Transit                        397.0      21.102073      46.185893
# Transit Timing Variations        3.0      79.783500      71.599884
#
#                                        min          25%           50%  \
# method
# Astrometry                      246.360000   438.770000    631.180000
# Eclipse Timing Variations      1916.250000  2900.000000   4343.500000
# Imaging                        4639.150000  8343.900000  27500.000000
# Microlensing                   1825.000000  2375.000000   3300.000000
# Orbital Brightness Modulation     0.240104     0.291496      0.342887
# Pulsar Timing                     0.090706    25.262000     66.541900
# Pulsation Timing Variations    1170.000000  1170.000000   1170.000000
# Radial Velocity                   0.736540    38.021000    360.200000
# Transit                           0.355000     3.160630      5.714932
# Transit Timing Variations        22.339500    39.675250     57.011000
#
#                                         75%            max
# method
# Astrometry                       823.590000    1016.000000
# Eclipse Timing Variations       5767.000000   10220.000000
# Imaging                        94250.000000  730000.000000
# Microlensing                    3550.000000    5100.000000
# Orbital Brightness Modulation      0.943908       1.544929
# Pulsar Timing                     98.211400   36525.000000
# Pulsation Timing Variations     1170.000000    1170.000000
# Radial Velocity                  982.000000   17337.500000
# Transit                           16.145700     331.600590
# Transit Timing Variations        108.505500     160.000000

# %%
# custom summary

df.groupby('method').aggregate(['min','max'])
# Out:
#                               number     orbital_period                 \
#                                  min max            min            max
# method
# Astrometry                         1   1     246.360000    1016.000000
# Eclipse Timing Variations          1   2    1916.250000   10220.000000
# Imaging                            1   4    4639.150000  730000.000000
# Microlensing                       1   2    1825.000000    5100.000000
# Orbital Brightness Modulation      1   2       0.240104       1.544929
# Pulsar Timing                      1   3       0.090706   36525.000000
# Pulsation Timing Variations        1   1    1170.000000    1170.000000
# Radial Velocity                    1   6       0.736540   17337.500000
# Transit                            1   7       0.355000     331.600590
# Transit Timing Variations          2   3      22.339500     160.000000
#
#                                  mass        distance           year
#                                   min    max      min      max   min   max
# method
# Astrometry                        NaN    NaN    14.98    20.77  2010  2013
# Eclipse Timing Variations      4.2000   6.05   130.72   500.00  2008  2012
# Imaging                           NaN    NaN     7.69   165.00  2004  2013
# Microlensing                      NaN    NaN  1760.00  7720.00  2004  2013
# Orbital Brightness Modulation     NaN    NaN  1180.00  1180.00  2011  2013
# Pulsar Timing                     NaN    NaN  1200.00  1200.00  1992  2011
# Pulsation Timing Variations       NaN    NaN      NaN      NaN  2007  2007
# Radial Velocity                0.0036  25.00     1.35   354.00  1989  2014
# Transit                        1.4700   1.47    38.00  8500.00  2002  2014
# Transit Timing Variations         NaN    NaN   339.00  2119.00  2011  2014

# %%
# multi groupby aggregate (pivot_table from scratch)

df = sns.load_dataset('titanic')
df.groupby(['sex','class'])['survived'].aggregate('mean').unstack()
# Out:
# class      First    Second     Third
# sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %%
# pivot_table

df.pivot_table('survived',index='sex',columns='class',aggfunc=np.mean)
# Out:
# class      First    Second     Third
# sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %%
# cut

names = pd.Series({'1':'A','2':'B','3':'C','4':'D','5':'E','6':'F'})
ages = pd.Series({'1':30,'2':11,'3':74,'4':55,'5':34,'6':26})
df = pd.DataFrame({'names':names,'ages':ages})
print(df)

df['age_groups_0'] = pd.cut(df['ages'],[0,20,40,60,80])
df['age_groups_1'] = pd.cut(df.ages,bins=[0,20,40,60,80],labels=['0-20','20-40','40-60','60-80'])
print(df)
# Out:
#   names  ages
# 1     A    30
# 2     B    11
# 3     C    74
# 4     D    55
# 5     E    34
# 6     F    26
#   names  ages age_groups_0 age_groups_1
# 1     A    30     (20, 40]        20-40
# 2     B    11      (0, 20]         0-20
# 3     C    74     (60, 80]        60-80
# 4     D    55     (40, 60]        40-60
# 5     E    34     (20, 40]        20-40
# 6     F    26     (20, 40]        20-40

# %%
# qcut

df = sns.load_dataset('titanic')
age = pd.cut(df['age'],[0,18,80])
print(df.pivot_table('survived',['sex',age],'class'))
fare = pd.qcut(df['fare'],3)
df.pivot_table('survived',['sex',age],[fare,'class'])
# Out:
# class               First    Second     Third
# sex    age
# female (0, 18]   0.909091  1.000000  0.511628
#        (18, 80]  0.972973  0.900000  0.423729
# male   (0, 18]   0.800000  0.600000  0.215686
#        (18, 80]  0.375000  0.071429  0.133663
# fare            (-0.001, 8.662]           (8.662, 26.0]                      \
# class                     First     Third         First    Second     Third
# sex    age
# female (0, 18]              NaN  0.700000           NaN  1.000000  0.583333
#        (18, 80]             NaN  0.523810           1.0  0.877551  0.433333
# male   (0, 18]              NaN  0.166667           NaN  0.500000  0.500000
#        (18, 80]             0.0  0.127389           0.0  0.086957  0.102564
#
# fare            (26.0, 512.329]
# class                     First Second     Third
# sex    age
# female (0, 18]         0.909091    1.0  0.111111
#        (18, 80]        0.972222    1.0  0.125000
# male   (0, 18]         0.800000    0.8  0.052632
#        (18, 80]        0.400000    0.0  0.500000

# %%
# aggfunc

df.pivot_table(index='sex', columns='class',aggfunc={'survived':sum, 'fare':'mean'})
# Out:
#               fare                       survived
# class        First     Second      Third    First Second Third
# sex
# female  106.125798  21.970121  16.118810       91     70    72
# male     67.226127  19.741782  12.661633       45     17    47

# %%
# eval

prng = np.random.default_rng(seed=0)

df = pd.DataFrame(rng.rand(10,3),columns=['A','B','C'])
print(df)
df.eval('D=(A+B)/(C-1)',inplace=True)
df['E']=(df['A']+df['B'])/(df['C']-1)
print(df)
# Out:
#           A         B         C
# 0  0.148141  0.981829  0.478370
# 1  0.497391  0.639473  0.368585
# 2  0.136900  0.822118  0.189848
# 3  0.511319  0.224317  0.097844
# 4  0.862192  0.972919  0.960835
# 5  0.906555  0.774047  0.333145
# 6  0.081101  0.407241  0.232234
# 7  0.132488  0.053427  0.725594
# 8  0.011427  0.770581  0.146947
# 9  0.079522  0.089603  0.672048
#           A         B         C          D          E
# 0  0.148141  0.981829  0.478370  -2.166231  -2.166231
# 1  0.497391  0.639473  0.368585  -1.800501  -1.800501
# 2  0.136900  0.822118  0.189848  -1.183751  -1.183751
# 3  0.511319  0.224317  0.097844  -0.815420  -0.815420
# 4  0.862192  0.972919  0.960835 -46.855483 -46.855483
# 5  0.906555  0.774047  0.333145  -2.520193  -2.520193
# 6  0.081101  0.407241  0.232234  -0.636057  -0.636057
# 7  0.132488  0.053427  0.725594  -0.677518  -0.677518
# 8  0.011427  0.770581  0.146947  -0.916717  -0.916717
# 9  0.079522  0.089603  0.672048  -0.515701  -0.515701

# %%
# query

df.query('A<0.5 and B>0.5')
# Out:
#           A         B         C         D         E
# 0  0.148141  0.981829  0.478370 -2.166231 -2.166231
# 1  0.497391  0.639473  0.368585 -1.800501 -1.800501
# 2  0.136900  0.822118  0.189848 -1.183751 -1.183751
# 8  0.011427  0.770581  0.146947 -0.916717 -0.916717
